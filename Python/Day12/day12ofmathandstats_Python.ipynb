# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %% [markdown]
# ### Correlation matrix for mtcars data

# %%
data = pd.read_csv('/content/mtcars.csv')

np.round(data.corr(),2)
# Out:
#        mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
# mpg   1.00 -0.85 -0.85 -0.78  0.68 -0.87  0.42  0.66  0.60  0.48 -0.55
# cyl  -0.85  1.00  0.90  0.83 -0.70  0.78 -0.59 -0.81 -0.52 -0.49  0.53
# disp -0.85  0.90  1.00  0.79 -0.71  0.89 -0.43 -0.71 -0.59 -0.56  0.39
# hp   -0.78  0.83  0.79  1.00 -0.45  0.66 -0.71 -0.72 -0.24 -0.13  0.75
# drat  0.68 -0.70 -0.71 -0.45  1.00 -0.71  0.09  0.44  0.71  0.70 -0.09
# wt   -0.87  0.78  0.89  0.66 -0.71  1.00 -0.17 -0.55 -0.69 -0.58  0.43
# qsec  0.42 -0.59 -0.43 -0.71  0.09 -0.17  1.00  0.74 -0.23 -0.21 -0.66
# vs    0.66 -0.81 -0.71 -0.72  0.44 -0.55  0.74  1.00  0.17  0.21 -0.57
# am    0.60 -0.52 -0.59 -0.24  0.71 -0.69 -0.23  0.17  1.00  0.79  0.06
# gear  0.48 -0.49 -0.56 -0.13  0.70 -0.58 -0.21  0.21  0.79  1.00  0.27
# carb -0.55  0.53  0.39  0.75 -0.09  0.43 -0.66 -0.57  0.06  0.27  1.00

# %% [markdown]
# ### This is correlation heatmap based on correlation matrix. The size of ellipse tells the positive and negative correlations

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.heatmap(data.corr(), vmin=-1, vmax=1, 
                 cmap=sns.diverging_palette(20, 220, as_cmap=True),
                 ax=ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Below is just the visually different version in case anyone just wants to see one part of the correlation since other half is just the repeatation

# %%
fig, ax = plt.subplots(figsize=(8, 6))
mask = np.triu(np.ones_like(data.corr()))
dataplot = sns.heatmap(data.corr(), cmap=sns.diverging_palette(20, 220, as_cmap=True), annot=True, mask=mask)
plt.show()

# %% [markdown]
# ## Various versions of scatter Plot for mtcars data

# %%
ax = data.plot.scatter(x='mpg', y='wt', figsize=(4, 4), marker='$\u25EF$')
ax.set_xlabel('MPG')
ax.set_ylabel('WT')


plt.tight_layout()
plt.show()

# %%
rng = np.random.RandomState(0)
sizes = 1000 * rng.rand(32)
ax = data.plot.scatter(x='mpg', y='wt',s=sizes, figsize=(4, 4), marker='*')
ax.set_xlabel('MPG')
ax.set_ylabel('WT')


plt.tight_layout()
plt.show()
